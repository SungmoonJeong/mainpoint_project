# %%
import pandas as pd

# %%
df = pd.read_csv("df_v_fianl.csv")

# %%
df
# Out:
#        국가    대륙  위험도  경보레벨 지역 유형  \
# 0      가나  아프리카  2.0   2.0    전체
# 1      가봉  아프리카  2.0   2.0    전체
# 2    가이아나    미주  NaN   NaN   NaN
# 3     감비아  아프리카  2.0   2.0    전체
# 4    과테말라    미주  2.0   2.0    전체
# ..    ...   ...  ...   ...   ...
# 180    피지    아주  1.0   1.0    전체
# 181   핀란드    유럽  NaN   NaN   NaN
# 182   필리핀    아주  4.0   4.0    일부
# 183   헝가리    유럽  NaN   NaN   NaN
# 184    호주    아주  NaN   NaN   NaN
#
#                                                   특이사항        작성일자
# 0                                                 전 지역  2022-08-02
# 1                                                 전 지역  2023-11-24
# 2                                                  NaN  2023-11-24
# 3                                                 전 지역  2022-08-02
# 4                                                 전 지역  2022-08-02
# ..                                                 ...         ...
# 180                                               전 지역  2023-11-24
# ...

# %%
df = df.fillna(0)

# %%
df
# Out:
#        국가    대륙  위험도  경보레벨 지역 유형  \
# 0      가나  아프리카  2.0   2.0    전체
# 1      가봉  아프리카  2.0   2.0    전체
# 2    가이아나    미주  NaN   NaN   NaN
# 3     감비아  아프리카  2.0   2.0    전체
# 4    과테말라    미주  2.0   2.0    전체
# ..    ...   ...  ...   ...   ...
# 180    피지    아주  1.0   1.0    전체
# 181   핀란드    유럽  NaN   NaN   NaN
# 182   필리핀    아주  4.0   4.0    일부
# 183   헝가리    유럽  NaN   NaN   NaN
# 184    호주    아주  NaN   NaN   NaN
#
#                                                   특이사항        작성일자
# 0                                                 전 지역  2022-08-02
# 1                                                 전 지역  2023-11-24
# 2                                                  NaN  2023-11-24
# 3                                                 전 지역  2022-08-02
# 4                                                 전 지역  2022-08-02
# ..                                                 ...         ...
# 180                                               전 지역  2023-11-24
# ...

# %%
df.to_csv("risk.csv")
